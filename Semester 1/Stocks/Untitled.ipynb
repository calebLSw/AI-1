# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_json("tsla.json")

# %%
sns.scatterplot(data=df, x="high", y="volume")
# Out:
# <AxesSubplot:xlabel='high', ylabel='volume'>

# %%
df["high"].corr(df["volume"])
# Out:
# -0.04379362079085321

# %% [markdown]
# # Concat - for rows, merge for columns
